# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 285
#     282     dt = t_end - t
#     284 Uold = U.copy()
# --> 285 U = step(U, dx, dy, dt, gamma, inflow)
#     286 t += dt
#     288 res = residual(U, Uold)
#
# Cell In[3], line 199, in step(U, dx, dy, dt, gamma, inflow_primitive)
#     197 Fx_full[:, :, 0] = rusanov_flux_x(UL, UR, gamma)
#     198 # interior faces
# --> 199 Fx_full[:, :, 1:-1] = Fx_int
#     200 # right boundary face between cols Nx (last interior) and Nx+1 (ghost)
#     201 UL = U[:, 1:-1, -2]
#
# ValueError: could not broadcast input array from shape (4,80,198) into shape (4,80,199)
