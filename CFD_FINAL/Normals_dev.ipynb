# %%
from Nozzle_1D import Nozzle
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
TestNozzle = Nozzle("inputs/Medium_inputs.nml")
TestNozzle.set_arrays()
TestNozzle.set_curved_geometry()
TestNozzle.plot_Geometry()
TestNozzle.set_initial_conditions()
TestNozzle.set_normals()
TestNozzle.compute_all_areas()
TestNozzle.plot_primitive("velocity")
TestNozzle.set_boundary_conditions()
#TestNozzle.plot_primitive("velocity")
TestNozzle.plot_Geometry()
#TestNozzle.plot_boundary_primitive("velocity")

# %%
plt.quiver(TestNozzle.xx_top_bottom,TestNozzle.yy_top_bottom,\
           (TestNozzle.nx_ny_top[0]),(TestNozzle.nx_ny_top[1]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.quiver(TestNozzle.xx_top_bottom,TestNozzle.yy_top_bottom,\
#       2            (TestNozzle.nx_ny_top[0]),(TestNozzle.nx_ny_top[1]))
#
# AttributeError: 'Nozzle' object has no attribute 'xx_top_bottom'

# %%
self = TestNozzle
self.plot_Geometry()
plt.quiver(self.xx_top_bottom[:,1:],self.yy_top_bottom[:,1:],self.nx_ny_top[0][1:,:],self.nx_ny_top[1][1:,:])
